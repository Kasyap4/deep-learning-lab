# %%
pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.12.0)

# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from tensorflow.keras.models import Sequential
#importing the required libraries

# %%
import tensorflow
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.layers import Dense,Input,Dropout,Conv2D,MaxPooling2D,Flatten

# %% [markdown]
# Q1) Understanding the Dataset and pre-processing

# %%
data=tf.keras.datasets.fashion_mnist

# %%
#Reading The Dataset
(x_train,y_train),(x_test,y_test)=data.load_data()

# %% [markdown]
# Displaying the Number of classes

# %%
#To find the no of Labels for the dataset using Y_train
num_classes = len(np.unique(y_train))

# %%
print ("Number of Classes:",num_classes)
# Out:
# Number of Classes: 10

# %%
y=x_train.shape
y[0]
# Out:
# 60000

# %% [markdown]
# Dimension of the image

# %%
img_height, img_width = x_train.shape[1], x_train.shape[2]
print("Image dimensions:", img_width, "x", img_height)
# Out:
# Image dimensions: 28 x 28

# %% [markdown]
# Displaying one image from each class

# %%
plt.figure(figsize=(10, 10))
for class_label  in range (num_classes):
    plt.subplot(5, 5, class_label + 1)
    plt.imshow(x_train[np.argmax(y_train == class_label)], cmap='gray')
    plt.title(f"Class {class_label}")
    plt.axis('off')
plt.show()

# %% [markdown]
# Performing Normalisation

# %%
x_train=x_train/255.0
x_test=x_test/255.0

# %% [markdown]
# Creation of FCNN model

# %%
model=tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[28,28],name="inputLayer"))
model.add(tf.keras.layers.Dense(300,activation="relu",name="hiddenlayer1"))
model.add(tf.keras.layers.Dense(100,activation="relu",name="hiddenlayer2"))
model.add(tf.keras.layers.Dense(10,activation="softmax",name="outputlayer"))

# %%
model.summary()#Summary of the Model
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inputLayer (Flatten)        (None, 784)               0
#
#  hiddenlayer1 (Dense)        (None, 300)               235500
#
#  hiddenlayer2 (Dense)        (None, 100)               30100
#
#  outputlayer (Dense)         (None, 10)                1010
#
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adamax',loss='sparse_categorical_crossentropy',metrics =['accuracy'])
#we can use different types of optimizers like adam,...etc here i have used adamax
#For loss i have used sparse categorical is most commonly used for classification and also extension for the cross entropy(Binary)

# %%
history=model.fit(x_train,y_train,epochs=20,validation_split=0.1,batch_size=16)
# Out:
# Epoch 1/20
# 3375/3375 [==============================] - 13s 4ms/step - loss: 0.4996 - accuracy: 0.8261 - val_loss: 0.4274 - val_accuracy: 0.8397
# Epoch 2/20
# 3375/3375 [==============================] - 15s 4ms/step - loss: 0.3746 - accuracy: 0.8653 - val_loss: 0.3492 - val_accuracy: 0.8702
# Epoch 3/20
# 3375/3375 [==============================] - 10s 3ms/step - loss: 0.3348 - accuracy: 0.8782 - val_loss: 0.3602 - val_accuracy: 0.8678
# Epoch 4/20
# 3375/3375 [==============================] - 12s 3ms/step - loss: 0.3111 - accuracy: 0.8858 - val_loss: 0.3297 - val_accuracy: 0.8788
# Epoch 5/20
# 3375/3375 [==============================] - 10s 3ms/step - loss: 0.2902 - accuracy: 0.8940 - val_loss: 0.3324 - val_accuracy: 0.8757
# Epoch 6/20
# 3375/3375 [==============================] - 10s 3ms/step - loss: 0.2747 - accuracy: 0.8991 - val_loss: 0.3199 - val_accuracy: 0.8880
# Epoch 7/20
# 3375/3375 [==============================] - 10s 3ms/step - loss: 0.2616 - accuracy: 0.9036 - val_loss: 0.3166 - val_accuracy: 0.8835
# Epoch 8/20
# 3375/3375 [==============================] - 10s 3ms/step - loss: 0.2490 - accuracy: 0.9079 - val_loss: 0.3281 - val_accuracy: 0.8805
# Epoch 9/20
# 3375/3375 [==============================] - 10s 3ms/step - loss: 0.2392 - accuracy: 0.9119 - val_loss: 0.3075 - val_accuracy: 0.8862
# Epoch 10/20
# 3375/3375 [==============================] - 10s 3ms/step - loss: 0.2300 - accuracy: 0.9153 - val_loss: 0.3124 - val_accuracy: 0.8853
# Epoch 11/20
# 3375/3375 [==============================] - 10s 3ms/step - loss: 0.2211 - accuracy: 0.9184 - val_loss: 0.3031 - val_accuracy: 0.8892
# Epoch 12/20
# 3375/3375 [==============================] - 10s 3ms/step - loss: 0.2117 - accuracy: 0.9222 - val_loss: 0.3037 - val_accuracy: 0.8907
# Epoch 13/20
# 3375/3375 [==============================] - 10s 3ms/step - loss: 0.2044 - accuracy: 0.9244 - val_loss: 0.3069 - val_accuracy: 0.8918
# Epoch 14/20
# 3375/3375 [==============================] - 10s 3ms/step - loss: 0.1966 - accuracy: 0.9277 - val_loss: 0.3156 - val_accuracy: 0.8872
# Epoch 15/20
# 3375/3375 [==============================] - 10s 3ms/step - loss: 0.1899 - accuracy: 0.9293 - val_loss: 0.3211 - val_accuracy: 0.8913
# Epoch 16/20
# 3375/3375 [==============================] - 9s 3ms/step - loss: 0.1837 - accuracy: 0.9320 - val_loss: 0.3190 - val_accuracy: 0.8913
# Epoch 17/20
# 3375/3375 [==============================] - 10s 3ms/step - loss: 0.1749 - accuracy: 0.9350 - val_loss: 0.3298 - val_accuracy: 0.8882
# Epoch 18/20
# 3375/3375 [==============================] - 10s 3ms/step - loss: 0.1707 - accuracy: 0.9360 - val_loss: 0.3181 - val_accuracy: 0.8980
# Epoch 19/20
# 3375/3375 [==============================] - 10s 3ms/step - loss: 0.1638 - accuracy: 0.9394 - val_loss: 0.3211 - val_accuracy: 0.8953
# Epoch 20/20
# 3375/3375 [==============================] - 10s 3ms/step - loss: 0.1573 - accuracy: 0.9415 - val_loss: 0.3177 - val_accuracy: 0.8947

# %%
# Plot performance curves for Fully connected neural network
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Value')
plt.title('FCNN Performance')
plt.show()

# %%
y_predicted = model.predict(x_test)
y_predicted[0]
# Out:
# 313/313 [==============================] - 0s 1ms/step
# array([2.11835260e-08, 1.29991362e-09, 1.20649002e-08, 6.02243366e-09,
#        1.24593775e-08, 4.02709884e-06, 1.92272000e-06, 2.20884744e-04,
#        2.41993146e-08, 9.99773085e-01], dtype=float32)

# %%
np.argmax(y_predicted[0])
# Out:
# 9

# %%
np.argmax(y_predicted[1])
# Out:
# 2

# %%
y_predicted_labels = [np.argmax(i) for i in y_predicted]
y_predicted_labels[:5]
# Out:
# [9, 2, 1, 1, 6]

# %% [markdown]
# Construction of confusion matrix

# %%
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_predicted_labels)
cm
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[867,   2,  21,  10,   6,   2,  82,   0,  10,   0],
#        [  3, 973,   1,  16,   4,   0,   2,   0,   1,   0],
#        [ 17,   1, 849,  12,  86,   0,  32,   0,   3,   0],
#        [ 33,   5,  13, 874,  49,   0,  22,   0,   4,   0],
#        [  2,   0, 102,  19, 848,   0,  25,   0,   4,   0],
#        [  0,   0,   0,   1,   0, 969,   0,  17,   1,  12],
#        [118,   1, 114,  26,  88,   0, 641,   0,  12,   0],
#        [  0,   0,   0,   0,   0,  16,   0, 963,   1,  20],
#        [  7,   0,   2,   5,   1,   2,   2,   3, 978,   0],
#        [  0,   0,   0,   0,   0,   6,   1,  30,   0, 963]], dtype=int32)>

# %%
import seaborn as sns
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot =True,fmt ='d')
plt.xlabel('Predicted')
plt.ylabel('truth')
# Out:
# Text(95.72222222222221, 0.5, 'truth')

# %% [markdown]
# Creation of CNN Model

# %%
#Building the CNN-1 Model with a filter size of 5
model_cnn1=Sequential()
model_cnn1.add(Input(shape=(28,28,1)))
model_cnn1.add(Conv2D(32,kernel_size=(5,5),activation="relu",padding="valid"))
model_cnn1.add(MaxPooling2D(pool_size=(2,2),strides=2))
#classification and Flattening
model_cnn1.add(Flatten())
model_cnn1.add(Dense(100,activation="relu"))
model_cnn1.add(Dense(10,activation="softmax"))

# %%
#created a cnn model with a filter 5*5
model_cnn1.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 24, 24, 32)        832
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 32)       0
#  2D)
#
#  flatten_3 (Flatten)         (None, 4608)              0
#
#  dense_5 (Dense)             (None, 100)               460900
#
#  dense_6 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 462,742
# Trainable params: 462,742
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Builfing the CNN-2 Model
model_cnn2=Sequential()
model_cnn2.add(Input(shape=(28,28,1)))
model_cnn2.add(Conv2D(32,kernel_size=(3,3),activation="relu",padding="valid"))
model_cnn2.add(MaxPooling2D(pool_size=(2,2),strides=2))
model_cnn2.add(Conv2D(32,kernel_size=(3,3),activation="relu",padding="valid"))
model_cnn2.add(MaxPooling2D(pool_size=(2,2),strides=2))
#classification part
model_cnn2.add(Flatten())
model_cnn2.add(Dense(100,activation="relu"))
model_cnn2.add(Dense(10,activation="softmax"))

# %%
#created a cnn model with a filter 3*3
model_cnn2.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_4 (MaxPooling  (None, 13, 13, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 11, 11, 32)        9248
#
#  max_pooling2d_5 (MaxPooling  (None, 5, 5, 32)         0
#  2D)
#
#  flatten_4 (Flatten)         (None, 800)               0
#
#  dense_7 (Dense)             (None, 100)               80100
#
#  dense_8 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 90,678
# Trainable params: 90,678
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer1=tf.keras.optimizers.Adam(learning_rate=0.0025)

# %%
model_cnn1.compile(loss="sparse_categorical_crossentropy",optimizer=optimizer1,metrics=["accuracy"])

# %%
history1=model_cnn1.fit(x_train,y_train,batch_size=250,epochs=30,validation_split=0.1)
# Out:
# Epoch 1/30
# 216/216 [==============================] - 2s 5ms/step - loss: 0.4776 - accuracy: 0.8317 - val_loss: 0.3318 - val_accuracy: 0.8840
# Epoch 2/30
# 216/216 [==============================] - 1s 4ms/step - loss: 0.3152 - accuracy: 0.8878 - val_loss: 0.2957 - val_accuracy: 0.8925
# Epoch 3/30
# 216/216 [==============================] - 1s 4ms/step - loss: 0.2697 - accuracy: 0.9029 - val_loss: 0.2907 - val_accuracy: 0.8952
# Epoch 4/30
# 216/216 [==============================] - 1s 4ms/step - loss: 0.2379 - accuracy: 0.9126 - val_loss: 0.2831 - val_accuracy: 0.9012
# Epoch 5/30
# 216/216 [==============================] - 1s 5ms/step - loss: 0.2141 - accuracy: 0.9211 - val_loss: 0.2645 - val_accuracy: 0.9057
# Epoch 6/30
# 216/216 [==============================] - 1s 5ms/step - loss: 0.1954 - accuracy: 0.9287 - val_loss: 0.2565 - val_accuracy: 0.9083
# Epoch 7/30
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1765 - accuracy: 0.9343 - val_loss: 0.2582 - val_accuracy: 0.9088
# Epoch 8/30
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1601 - accuracy: 0.9399 - val_loss: 0.2542 - val_accuracy: 0.9098
# Epoch 9/30
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1448 - accuracy: 0.9461 - val_loss: 0.2609 - val_accuracy: 0.9112
# Epoch 10/30
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1275 - accuracy: 0.9531 - val_loss: 0.2756 - val_accuracy: 0.9125
# Epoch 11/30
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1176 - accuracy: 0.9566 - val_loss: 0.2619 - val_accuracy: 0.9127
# Epoch 12/30
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1059 - accuracy: 0.9611 - val_loss: 0.2711 - val_accuracy: 0.9103
# Epoch 13/30
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0932 - accuracy: 0.9649 - val_loss: 0.2870 - val_accuracy: 0.9168
# Epoch 14/30
# 216/216 [==============================] - 1s 4ms/step - loss: 0.0861 - accuracy: 0.9687 - val_loss: 0.3154 - val_accuracy: 0.9102
# Epoch 15/30
# 216/216 [==============================] - 1s 4ms/step - loss: 0.0783 - accuracy: 0.9710 - val_loss: 0.3014 - val_accuracy: 0.9102
# Epoch 16/30
# 216/216 [==============================] - 1s 4ms/step - loss: 0.0682 - accuracy: 0.9753 - val_loss: 0.3460 - val_accuracy: 0.9100
# Epoch 17/30
# 216/216 [==============================] - 1s 4ms/step - loss: 0.0603 - accuracy: 0.9775 - val_loss: 0.3291 - val_accuracy: 0.9127
# Epoch 18/30
# 216/216 [==============================] - 1s 4ms/step - loss: 0.0495 - accuracy: 0.9828 - val_loss: 0.3683 - val_accuracy: 0.9107
# Epoch 19/30
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0524 - accuracy: 0.9810 - val_loss: 0.3731 - val_accuracy: 0.9095
# Epoch 20/30
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0450 - accuracy: 0.9841 - val_loss: 0.4105 - val_accuracy: 0.9057
# Epoch 21/30
# 216/216 [==============================] - 1s 4ms/step - loss: 0.0465 - accuracy: 0.9831 - val_loss: 0.3927 - val_accuracy: 0.9082
# Epoch 22/30
# 216/216 [==============================] - 1s 4ms/step - loss: 0.0354 - accuracy: 0.9876 - val_loss: 0.4490 - val_accuracy: 0.9100
# Epoch 23/30
# 216/216 [==============================] - 1s 4ms/step - loss: 0.0330 - accuracy: 0.9886 - val_loss: 0.4233 - val_accuracy: 0.9103
# Epoch 24/30
# 216/216 [==============================] - 1s 4ms/step - loss: 0.0356 - accuracy: 0.9874 - val_loss: 0.4533 - val_accuracy: 0.9105
# Epoch 25/30
# 216/216 [==============================] - 1s 4ms/step - loss: 0.0280 - accuracy: 0.9904 - val_loss: 0.4586 - val_accuracy: 0.9117
# Epoch 26/30
# 216/216 [==============================] - 1s 4ms/step - loss: 0.0270 - accuracy: 0.9904 - val_loss: 0.4847 - val_accuracy: 0.9087
# Epoch 27/30
# 216/216 [==============================] - 1s 4ms/step - loss: 0.0312 - accuracy: 0.9886 - val_loss: 0.4809 - val_accuracy: 0.9122
# Epoch 28/30
# 216/216 [==============================] - 1s 4ms/step - loss: 0.0257 - accuracy: 0.9915 - val_loss: 0.5451 - val_accuracy: 0.9085
# Epoch 29/30
# 216/216 [==============================] - 1s 4ms/step - loss: 0.0221 - accuracy: 0.9926 - val_loss: 0.5052 - val_accuracy: 0.9063
# Epoch 30/30
# 216/216 [==============================] - 1s 4ms/step - loss: 0.0237 - accuracy: 0.9917 - val_loss: 0.5934 - val_accuracy: 0.9028

# %%
y_predicted = model.predict(x_test)
y_predicted[0]
# Out:
# 313/313 [==============================] - 0s 1ms/step
# array([2.11835260e-08, 1.29991362e-09, 1.20649002e-08, 6.02243366e-09,
#        1.24593775e-08, 4.02709884e-06, 1.92272000e-06, 2.20884744e-04,
#        2.41993146e-08, 9.99773085e-01], dtype=float32)

# %%
np.argmax(y_predicted[0])
# Out:
# 9

# %%
np.argmax(y_predicted[1])
# Out:
# 2

# %%
y_predicted_labels = [np.argmax(i) for i in y_predicted]
y_predicted_labels[:5]
# Out:
# [9, 2, 1, 1, 6]

# %%
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_predicted_labels)
cm
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[867,   2,  21,  10,   6,   2,  82,   0,  10,   0],
#        [  3, 973,   1,  16,   4,   0,   2,   0,   1,   0],
#        [ 17,   1, 849,  12,  86,   0,  32,   0,   3,   0],
#        [ 33,   5,  13, 874,  49,   0,  22,   0,   4,   0],
#        [  2,   0, 102,  19, 848,   0,  25,   0,   4,   0],
#        [  0,   0,   0,   1,   0, 969,   0,  17,   1,  12],
#        [118,   1, 114,  26,  88,   0, 641,   0,  12,   0],
#        [  0,   0,   0,   0,   0,  16,   0, 963,   1,  20],
#        [  7,   0,   2,   5,   1,   2,   2,   3, 978,   0],
#        [  0,   0,   0,   0,   0,   6,   1,  30,   0, 963]], dtype=int32)>

# %%
import seaborn as sns
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot =True,fmt ='d')
plt.xlabel('Predicted')
plt.ylabel('truth')
# Out:
# Text(95.72222222222221, 0.5, 'truth')

# %%
plt.plot(history1.history['accuracy'])

# %%
optimizer2=tf.keras.optimizers.Adam(learning_rate=0.0025)

# %%
model_cnn2.compile(loss="sparse_categorical_crossentropy",optimizer=optimizer2,metrics=["accuracy"])

# %%
history2=model_cnn2.fit(x_train,y_train,batch_size=250,epochs=30,validation_split=0.15)
# Out:
# Epoch 1/30
# 204/204 [==============================] - 3s 6ms/step - loss: 0.5971 - accuracy: 0.7853 - val_loss: 0.4298 - val_accuracy: 0.8457
# Epoch 2/30
# 204/204 [==============================] - 1s 5ms/step - loss: 0.3679 - accuracy: 0.8678 - val_loss: 0.3415 - val_accuracy: 0.8778
# Epoch 3/30
# 204/204 [==============================] - 1s 5ms/step - loss: 0.3229 - accuracy: 0.8822 - val_loss: 0.3387 - val_accuracy: 0.8778
# Epoch 4/30
# 204/204 [==============================] - 1s 5ms/step - loss: 0.2914 - accuracy: 0.8943 - val_loss: 0.3041 - val_accuracy: 0.8890
# Epoch 5/30
# 204/204 [==============================] - 1s 5ms/step - loss: 0.2712 - accuracy: 0.9015 - val_loss: 0.2858 - val_accuracy: 0.8953
# Epoch 6/30
# 204/204 [==============================] - 1s 5ms/step - loss: 0.2492 - accuracy: 0.9087 - val_loss: 0.2772 - val_accuracy: 0.8972
# Epoch 7/30
# 204/204 [==============================] - 1s 6ms/step - loss: 0.2368 - accuracy: 0.9132 - val_loss: 0.2604 - val_accuracy: 0.9033
# Epoch 8/30
# 204/204 [==============================] - 1s 6ms/step - loss: 0.2154 - accuracy: 0.9204 - val_loss: 0.2626 - val_accuracy: 0.9024
# Epoch 9/30
# 204/204 [==============================] - 1s 5ms/step - loss: 0.2077 - accuracy: 0.9245 - val_loss: 0.2727 - val_accuracy: 0.9003
# Epoch 10/30
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1960 - accuracy: 0.9273 - val_loss: 0.2488 - val_accuracy: 0.9111
# Epoch 11/30
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1797 - accuracy: 0.9347 - val_loss: 0.2631 - val_accuracy: 0.9021
# Epoch 12/30
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1747 - accuracy: 0.9356 - val_loss: 0.2729 - val_accuracy: 0.8992
# Epoch 13/30
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1639 - accuracy: 0.9386 - val_loss: 0.2662 - val_accuracy: 0.9048
# Epoch 14/30
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1488 - accuracy: 0.9445 - val_loss: 0.2701 - val_accuracy: 0.9073
# Epoch 15/30
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1413 - accuracy: 0.9483 - val_loss: 0.2580 - val_accuracy: 0.9091
# Epoch 16/30
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1354 - accuracy: 0.9489 - val_loss: 0.2609 - val_accuracy: 0.9091
# Epoch 17/30
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1231 - accuracy: 0.9553 - val_loss: 0.2625 - val_accuracy: 0.9082
# Epoch 18/30
# 204/204 [==============================] - 1s 5ms/step - loss: 0.1192 - accuracy: 0.9557 - val_loss: 0.2806 - val_accuracy: 0.9084
# Epoch 19/30
# 204/204 [==============================] - 1s 6ms/step - loss: 0.1092 - accuracy: 0.9596 - val_loss: 0.2953 - val_accuracy: 0.9046
# Epoch 20/30
# 204/204 [==============================] - 1s 6ms/step - loss: 0.1027 - accuracy: 0.9622 - val_loss: 0.3005 - val_accuracy: 0.9063
# Epoch 21/30
# 204/204 [==============================] - 1s 5ms/step - loss: 0.0971 - accuracy: 0.9643 - val_loss: 0.3003 - val_accuracy: 0.9106
# Epoch 22/30
# 204/204 [==============================] - 1s 5ms/step - loss: 0.0902 - accuracy: 0.9669 - val_loss: 0.3181 - val_accuracy: 0.9082
# Epoch 23/30
# 204/204 [==============================] - 1s 5ms/step - loss: 0.0879 - accuracy: 0.9673 - val_loss: 0.3447 - val_accuracy: 0.9036
# Epoch 24/30
# 204/204 [==============================] - 1s 5ms/step - loss: 0.0846 - accuracy: 0.9688 - val_loss: 0.3225 - val_accuracy: 0.9077
# Epoch 25/30
# 204/204 [==============================] - 1s 5ms/step - loss: 0.0748 - accuracy: 0.9719 - val_loss: 0.3456 - val_accuracy: 0.9106
# Epoch 26/30
# 204/204 [==============================] - 1s 5ms/step - loss: 0.0640 - accuracy: 0.9767 - val_loss: 0.3506 - val_accuracy: 0.9089
# Epoch 27/30
# 204/204 [==============================] - 1s 5ms/step - loss: 0.0630 - accuracy: 0.9775 - val_loss: 0.3747 - val_accuracy: 0.9066
# Epoch 28/30
# 204/204 [==============================] - 1s 5ms/step - loss: 0.0588 - accuracy: 0.9779 - val_loss: 0.3875 - val_accuracy: 0.9063
# Epoch 29/30
# 204/204 [==============================] - 1s 5ms/step - loss: 0.0530 - accuracy: 0.9806 - val_loss: 0.3997 - val_accuracy: 0.9054
# Epoch 30/30
# 204/204 [==============================] - 1s 5ms/step - loss: 0.0498 - accuracy: 0.9820 - val_loss: 0.4137 - val_accuracy: 0.9098

# %%
plt.plot(history2.history['accuracy'])

# %%
loss1,accuracy=model_cnn1.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.6176 - accuracy: 0.9040

# %%
loss2,accuracy=model_cnn2.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4513 - accuracy: 0.9066

# %%
plt.plot(history1.history['loss'], label='train_loss')
plt.plot(history1.history['val_loss'], label='val_loss')
plt.plot(history1.history['accuracy'], label='train_accuracy')
plt.plot(history1.history['val_accuracy'], label='val_accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Value')
plt.title('CNN1 Performance')
plt.show()

# %%
plt.plot(history2.history['loss'], label='train_loss')
plt.plot(history2.history['val_loss'], label='val_loss')
plt.plot(history2.history['accuracy'], label='train_accuracy')
plt.plot(history2.history['val_accuracy'], label='val_accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Value')
plt.title('CNN2 Performance')
plt.show()

# %% [markdown]
# Comparsion of Performances Between Fully connected neural network and Convolution neural network

# %%
training_accuracy_fcnn = history.history['accuracy']
validation_accuracy_fcnn = history.history['val_accuracy']
training_accuracy_cnn1 = history1.history['accuracy']
validation_accuracy_cnn1 = history1.history['val_accuracy']
plt.plot(training_accuracy_fcnn, label='Training Accuracy1')
plt.plot(validation_accuracy_fcnn, label='Validation Accuracy1')
plt.plot(training_accuracy_cnn1, label='Training Accuracy2')
plt.plot(validation_accuracy_cnn1, label='Validation Accuracy2')
plt.legend()

# %%
training_accuracy_fcnn = history.history['accuracy']
validation_accuracy_fcnn = history.history['val_accuracy']
training_accuracy_cnn2 = history2.history['accuracy']
validation_accuracy_cnn2 = history2.history['val_accuracy']
plt.plot(training_accuracy_fcnn, label='Training Accuracy1')
plt.plot(validation_accuracy_fcnn, label='Validation Accuracy1')
plt.plot(training_accuracy_cnn2, label='Training Accuracy2')
plt.plot(validation_accuracy_cnn2, label='Validation Accuracy2')
plt.legend()

# %%
#### As we can clearly observe from both the graph plots that both the CNN1 and CNN2 models provide much higher accuracy than the FCNN

# %%
## Q5) Compare the number of parameters in the FCNN and the CNN

# %%
#### The number of parameters in FCNN are 266610 while the number of parameters in CNN1 and CNN2 are 462742 and 471478 respectively

# %%
## Q6) Discuss the computational efficiency of both networks. Which one took longer to train and why?

# %%
#### The computational efficiency order is CNN2>CNN1>FCNN. The training accuracy score and the validation accuracy score define the performance of the models and it is clear that CNN2 is better than CNN1 which is better than FCNN.

# %%
#### It took longer time to train CNN2 than CNN1 which took more time than FCNN. The reason for that is that CNN2 contained the most number of parameters followed by CNN1 and FCNN. The increased number of parameters resulted in the computation taking more time
